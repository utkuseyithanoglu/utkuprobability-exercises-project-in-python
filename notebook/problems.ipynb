# %% [markdown]
# # Probability exercises

# %% [markdown]
# ## Exercise 1
#
# Two dices are thrown once and the total score is observed. Use a simulation to find the estimated probability that the total score is even or greater than 7.  A simulation is a repetition of the same experiment multiple times to observe its behavior:
#
# - Run the experiment 1000 times (roll 2 dice 1000 times, and sum the number of both dices).
# - Keep track of the number of times that the sum was either greater than 7 or an even number.
# - Divide the number from step 2 by the number of iterations (1000).

# %%
# TODO

a=0
d=[]
for i in range(1000):
    dice_sum=np.random.randint(1,7)+np.random.randint(1,7)
    d.append(dice_sum)
    if dice_sum>7 or dice_sum%2==0:
        a+=1

print(f"this much sucsesfull {a}")
print(f"dice_probability = {a/1000}")
"""

def dice(n):
    a=0
    d=[]
    for i in range(n):
        dices=np.random.randint(1,7)+np.random.randint(1,7)
        d.append(dices)
        if dices>7 or dices%2==0:
             a+=1
    return a
    print(a)
dice(1000)
print(f"probibility= {dice(1000)/1000}")
"""
# Out:
# this much sucsesfull 645
# dice_probability = 0.645
# '\n\ndef dice(n):\n    a=0\n    d=[]\n    for i in range(n):\n        dices=np.random.randint(1,7)+np.random.randint(1,7)\n        d.append(dices)\n        if dices>7 or dices%2==0:\n             a+=1\n    return a\n    print(a)\ndice(1000)\nprint(f"probibility= {dice(1000)/1000}")\n'

# %% [markdown]
# exercise 3 ım trying the make
#
# Using names.txt (right click and 'Save Link/Target As...'), a 46K text file containing over five-thousand first names, begin by sorting it into alphabetical order. Then working out the alphabetical value for each name, multiply this value by its alphabetical position in the list to obtain a name score.
#
# For example, when the list is sorted into alphabetical order, COLIN, which is worth
# , is the 938x53=49714
# th name in the list. So, COLIN would obtain a score of
# .
#
# What is the total of all the name scores in the file?

# %%
#chatgpt yardım etti chatgpt helped me in this question

df=pd.read_csv("https://projecteuler.net/resources/documents/0022_names.txt",header=None)
df
# Out:
#    0         1      2        3          4         5      6      7     \
# 0  MARY  PATRICIA  LINDA  BARBARA  ELIZABETH  JENNIFER  MARIA  SUSAN
#
#        8        9     ...      5153  5154     5155  5156 5157   5158    5159  \
# 0  MARGARET  DOROTHY  ...  VINCENZO  SHON  LYNWOOD  JERE  HAI  ELDEN  DORSEY
#
#      5160       5161    5162
# 0  DARELL  BRODERICK  ALONSO
#
# [1 rows x 5163 columns]

# %%
names=[]
for i in range (len(df.columns)):
    names.append(str(df.iloc[0,i]))
names.sort()
letters_of_mycode=','.join(names)#bu str ye çeviriyo v
letters_of_mycode.split(',')
characters = []
for b in names:
    characters.append(list(b))
characters
# Out:
# [['A', 'A', 'R', 'O', 'N'],
#  ['A', 'B', 'B', 'E', 'Y'],
#  ['A', 'B', 'B', 'I', 'E'],
#  ['A', 'B', 'B', 'Y'],
#  ['A', 'B', 'D', 'U', 'L'],
#  ['A', 'B', 'E'],
#  ['A', 'B', 'E', 'L'],
#  ['A', 'B', 'I', 'G', 'A', 'I', 'L'],
#  ['A', 'B', 'R', 'A', 'H', 'A', 'M'],
#  ['A', 'B', 'R', 'A', 'M'],
#  ['A', 'D', 'A'],
#  ['A', 'D', 'A', 'H'],
#  ['A', 'D', 'A', 'L', 'B', 'E', 'R', 'T', 'O'],
#  ['A', 'D', 'A', 'L', 'I', 'N', 'E'],
#  ['A', 'D', 'A', 'M'],
#  ['A', 'D', 'A', 'N'],
#  ['A', 'D', 'D', 'I', 'E'],
#  ['A', 'D', 'E', 'L', 'A'],
#  ['A', 'D', 'E', 'L', 'A', 'I', 'D', 'A'],
#  ['A', 'D', 'E', 'L', 'A', 'I', 'D', 'E'],
#  ['A', 'D', 'E', 'L', 'E'],
#  ['A', 'D', 'E', 'L', 'I', 'A'],
#  ['A', 'D', 'E', 'L', 'I', 'N', 'A'],
#  ['A', 'D', 'E', 'L', 'I', 'N', 'E'],
#  ['A', 'D', 'E', 'L', 'L'],
#  ['A', 'D', 'E', 'L', 'L', 'A'],
#  ['A', 'D', 'E', 'L', 'L', 'E'],
#  ['A', 'D', 'E', 'N', 'A'],
#  ['A', 'D', 'I', 'N', 'A'],
#  ['A', 'D', 'O', 'L', 'F', 'O'],
# ...

# %%
sns.histplot(d,color='red',bins=20,linewidth=2,edgecolor='green')
plt.grid()
plt.title("excersize 1 histplot")
# Out:
# Text(0.5, 1.0, 'excersize 1 histplot')

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import random

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Exercise 2
#
# A box contains 10 white balls, 20 red balls and 30 green balls. If we take 5 balls from the box with replacement (we take the ball, observe what color it is and put it back into the box). We want to know the probability of:
#
# 1. Take 3 white and 2 red.
# 2. Take all of the same color.
#
# Run the experiment 1000 times and calculate the above probabilities.

# %%
step1=0
step2=0
for b in range(1000):
    r=0
    g=0
    w=0
    box=['R','R','W','G','G','G']
    for i in range(5):
        a = random.choice(box)
        if a=='R':
            r+=1
        elif a=='W':
            w+=1
        else:
            g+=1
        if w==3 and r==2:
            step1+=1
        if w==5 or r==5 or g==5:
            step2+=1
print(g,w,r)
print(f"step 1 result is {step1/1000},step 2 result is {step2/1000}")
# Out:
# 3 1 1
# step 1 result is 0.004,step 2 result is 0.04

# %% [markdown]
# If we list all the natural numbers below 10 that are multiples of or 3,5 we get 3,5,6 and 9. The sum of these multiples is 23 .Find the sum of all the multiples of 3 or 5 below 1000
# .

# %%
div=0
for i in range(1000):
    if i%3==0 or i%5==0:
        div+=i
print(f"the answer is {div}")
# Out:
# the answer is 233168

# %% [markdown]
# In the United Kingdom the currency is made up of pound (£) and pence (p). There are eight coins in general circulation:
#
# 1p, 2p, 5p, 10p, 20p, 50p, £1 (100p), and £2 (200p).
# It is possible to make £2 in the following way:
#
# 1×£1 + 1×50p + 2×20p + 1×5p + 1×2p + 3×1p
# How many different ways can £2 be made using any number of coins?

# %%
cost=0
count=0
box=[1,2,5,10,20,50,100,200]
a = random.choice(box)
while cost<300:
    count+=1
    cost+=a
    if cost==300:
        break
print(count)
# Out:
# 300

# %% [markdown]
# By considering the terms in the Fibonacci sequence whose values do not exceed four million, find the sum of the even-valued terms.

# %%
a=1
b=2
even_numbers=0
while b<4000000:
    if b%2==0:
        even_numbers+=b
    a,b=b,a+b
print(f"the results is {even_numbers}")
# Out:
# the results is 4613732

# %% [markdown]
# What is the index of the first term in the Fibonacci sequence to contain
# 1000 digits?

# %%
f1=1
f2=1
f_next=0
count=2
fibo=[f1,f2]
while fibo[-1]<=1000:
    f_next=f1+f2
    fibo.append(f_next)
    f1,f2=f2,f_next
    count+=1
print(count)
# Out:
# 17
